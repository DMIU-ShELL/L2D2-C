# %%
import json
import pickle
import numpy as np
import torch
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
# def load_data(fpath, num_tasks):
#     precision_matrices = []
#     for task_idx in range(1, num_tasks+1):
#         with open(fpath.format(task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
#     return precision_matrices

def load_data(fpath, num_runs, num_tasks):
    precision_matrices = []
    for run_idx in range(1, num_runs+1):
        for task_idx in range(1, num_tasks+1):
            with open(fpath.format(run_idx, task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
    return precision_matrices

# %%
path = './log/CTgraph-v0-ppo-scp-with-masked-importances/211129-192254/'
with open('{0}/config.json'.format(path), 'r') as f: 
    config = json.load(f)
num_tasks = config['cl_num_tasks']
num_learning_blocks = config['cl_num_learn_blocks'] # number of times/runs all tasks are repeatedly trained on.

# %% [markdown]
# ### Per task precision matrices

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-run-{0}-task-{1}.bin'
precision_matrices = load_data(fpath, num_learning_blocks, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i % num_tasks +1))
    print('-----> pm, task {0}'.format(i % num_tasks +1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.0011566
# value.min(): 0.0
# percentage of used params: 74.50%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.059888
# value.min(): 0.0
# percentage of used params: 75.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 6.9872284
# value.min(): 0.0
# percentage of used params: 62.63%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.695663
# value.min(): 0.0
# percentage of used params: 85.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 0.9611561
# value.min(): 0.0
# percentage of used params: 66.25%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.5053585
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1887.5858
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.2905
# value.min(): 1045.9596
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 27.976675
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.7364018
# value.min(): 0.0
# percentage of used params: 73.89%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.012061
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.624698
# value.min(): 0.0
# percentage of used params: 52.18%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.0535812
# value.min(): 0.0
# percentage of used params: 73.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.7942104
# value.min(): 0.0
# percentage of used params: 35.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7018397
# value.min(): 0.0
# percentage of used params: 53.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2296.8254
# value.min(): 0.0
# percentage of used params: 53.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.7385
# value.min(): 1056.4788
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 34.117138
# value.min(): 0.0
# percentage of used params: 53.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.5631595
# value.min(): 0.0
# percentage of used params: 78.37%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.672022
# value.min(): 0.0
# percentage of used params: 80.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 16.28584
# value.min(): 0.0
# percentage of used params: 66.20%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.8683338
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 7.6236434
# value.min(): 0.0
# percentage of used params: 66.99%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.4855927
# value.min(): 0.0
# percentage of used params: 85.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3412.534
# value.min(): 0.0
# percentage of used params: 85.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.3639
# value.min(): 1047.4039
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 50.1032
# value.min(): 0.0
# percentage of used params: 85.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.1520715
# value.min(): 0.0
# percentage of used params: 75.62%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.4583983
# value.min(): 0.0
# percentage of used params: 78.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.217508
# value.min(): 0.0
# percentage of used params: 57.17%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.9904591
# value.min(): 0.0
# percentage of used params: 79.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 9.125169
# value.min(): 0.0
# percentage of used params: 44.68%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.2013388
# value.min(): 0.0
# percentage of used params: 64.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1824.9187
# value.min(): 0.0
# percentage of used params: 64.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1101.0488
# value.min(): 1044.6753
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 26.544783
# value.min(): 0.0
# percentage of used params: 64.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.9428331
# value.min(): 0.0
# percentage of used params: 76.68%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.9808484
# value.min(): 0.0
# percentage of used params: 79.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 6.0431576
# value.min(): 0.0
# percentage of used params: 62.11%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.387519
# value.min(): 0.0
# percentage of used params: 86.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.3354301
# value.min(): 0.0
# percentage of used params: 60.54%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.3733431
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1919.6185
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1100.3309
# value.min(): 1048.5533
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 28.02698
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.7259345
# value.min(): 0.0
# percentage of used params: 72.58%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.0746036
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 14.200516
# value.min(): 0.0
# percentage of used params: 50.01%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 4.226205
# value.min(): 0.0
# percentage of used params: 72.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 10.395056
# value.min(): 0.0
# percentage of used params: 35.68%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.175136
# value.min(): 0.0
# percentage of used params: 56.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2106.2102
# value.min(): 0.0
# percentage of used params: 56.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1090.0963
# value.min(): 1052.4167
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 31.081718
# value.min(): 0.0
# percentage of used params: 56.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.9440124
# value.min(): 0.0
# percentage of used params: 72.81%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.0016181
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.131833
# value.min(): 0.0
# percentage of used params: 54.80%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.6242677
# value.min(): 0.0
# percentage of used params: 81.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 4.13593
# value.min(): 0.0
# percentage of used params: 52.55%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.9891472
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2913.2065
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1087.1162
# value.min(): 1050.8241
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 43.075058
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.2509713
# value.min(): 0.0
# percentage of used params: 71.48%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.564594
# value.min(): 0.0
# percentage of used params: 74.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.371686
# value.min(): 0.0
# percentage of used params: 48.30%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.9161736
# value.min(): 0.0
# percentage of used params: 71.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 12.556162
# value.min(): 0.0
# percentage of used params: 33.07%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.3766696
# value.min(): 0.0
# percentage of used params: 52.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3087.6887
# value.min(): 0.0
# percentage of used params: 52.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1086.7153
# value.min(): 1048.7771
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 45.443905
# value.min(): 0.0
# percentage of used params: 52.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.1778378
# value.min(): 0.0
# percentage of used params: 71.67%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.2400134
# value.min(): 0.0
# percentage of used params: 74.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 14.410634
# value.min(): 0.0
# percentage of used params: 51.82%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.5654442
# value.min(): 0.0
# percentage of used params: 79.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.4760027
# value.min(): 0.0
# percentage of used params: 50.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.84977
# value.min(): 0.0
# percentage of used params: 85.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3681.2637
# value.min(): 0.0
# percentage of used params: 85.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1079.826
# value.min(): 1057.7329
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 54.731895
# value.min(): 0.0
# percentage of used params: 85.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 9.206854
# value.min(): 0.0
# percentage of used params: 76.11%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 9.886142
# value.min(): 0.0
# percentage of used params: 79.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 16.983057
# value.min(): 0.0
# percentage of used params: 55.79%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 3.4892747
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 21.67328
# value.min(): 0.0
# percentage of used params: 42.16%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.8691308
# value.min(): 0.0
# percentage of used params: 60.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4392.124
# value.min(): 0.0
# percentage of used params: 60.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.063
# value.min(): 1058.0214
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 65.61902
# value.min(): 0.0
# percentage of used params: 60.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.6328816
# value.min(): 0.0
# percentage of used params: 73.56%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.7039638
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 11.377945
# value.min(): 0.0
# percentage of used params: 54.81%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.9605817
# value.min(): 0.0
# percentage of used params: 82.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.3264513
# value.min(): 0.0
# percentage of used params: 52.96%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7221906
# value.min(): 0.0
# percentage of used params: 82.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2383.6155
# value.min(): 0.0
# percentage of used params: 82.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.1327
# value.min(): 1060.5563
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 35.291733
# value.min(): 0.0
# percentage of used params: 82.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.6538806
# value.min(): 0.0
# percentage of used params: 70.10%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.997228
# value.min(): 0.0
# percentage of used params: 73.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 11.835526
# value.min(): 0.0
# percentage of used params: 45.85%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.3491085
# value.min(): 0.0
# percentage of used params: 69.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 13.166798
# value.min(): 0.0
# percentage of used params: 31.88%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.4973888
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3344.8428
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1080.019
# value.min(): 1056.8228
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 50.000664
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3        4   \
# tasks_idx                          task 1   task 2   task 1   task 2   task 1
# network.phi_body.layers.0.weight  74.4952   73.887  78.3678  75.6154  76.6827
# network.phi_body.layers.0.bias       75.5     76.5       80     78.5     79.5
# network.phi_body.layers.1.weight  62.6275  52.1775   66.195    57.17  62.1075
# network.phi_body.layers.1.bias       85.5       73     86.5       79       86
# network.phi_body.layers.2.weight    66.25   35.725  66.9875  44.6825    60.54
# network.phi_body.layers.2.bias       86.5     53.5     85.5     64.5       88
# network.fc_action.weight             86.5     53.5     85.5     64.5       88
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight             86.5     53.5     85.5     64.5       88
# network.fc_critic.bias                100      100      100      100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 2   task 1   task 2   task 1   task 2
# network.phi_body.layers.0.weight  72.5841  72.8077  71.4784  71.6683  76.1058
# network.phi_body.layers.0.bias         76       76     74.5     74.5       79
# network.phi_body.layers.1.weight  50.0075  54.8025   48.305   51.825    55.79
# network.phi_body.layers.1.bias       72.5       81       71       79     76.5
# network.phi_body.layers.2.weight    35.68  52.5475    33.07  50.1425    42.16
# network.phi_body.layers.2.bias         56     83.5       52       85     60.5
# network.fc_action.weight               56     83.5       52       85     60.5
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               56     83.5       52       85     60.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                          task 1   task 2
# network.phi_body.layers.0.weight  73.5649  70.0986
# network.phi_body.layers.0.bias         76       73
# network.phi_body.layers.1.weight  54.8125    45.85
# network.phi_body.layers.1.bias         82       69
# network.phi_body.layers.2.weight   52.965    31.88
# network.phi_body.layers.2.bias       82.5       57
# network.fc_action.weight             82.5       57
# network.fc_action.bias                100      100
# network.fc_critic.weight             82.5       57
# network.fc_critic.bias                100      100

# %% [markdown]
# ### Moving average precision matrices across tasks

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-movavg-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-run-{0}-task-{1}.bin'
precision_matrices = load_data(fpath, num_learning_blocks, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i+1))
    print('-----> pma, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pma, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.2508674
# value.min(): 0.0
# percentage of used params: 74.50%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.294916
# value.min(): 0.0
# percentage of used params: 75.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.2404213
# value.min(): 0.0
# percentage of used params: 62.63%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.2717472
# value.min(): 0.0
# percentage of used params: 85.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 0.72086704
# value.min(): 0.0
# percentage of used params: 66.25%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.3790189
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1415.6893
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 808.7179
# value.min(): 784.4697
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 20.982506
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 12.0
# value.min(): 12.0
# percentage of used params: 100.00%
# -----> pma, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.0732055
# value.min(): 0.0
# percentage of used params: 86.96%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.5035915
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.7185235
# value.min(): 0.0
# percentage of used params: 77.03%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5401859
# value.min(): 0.0
# percentage of used params: 93.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.10805
# value.min(): 0.0
# percentage of used params: 74.21%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.2996192
# value.min(): 0.0
# percentage of used params: 90.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1909.3225
# value.min(): 0.0
# percentage of used params: 90.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1010.75726
# value.min(): 994.5386
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 28.36582
# value.min(): 0.0
# percentage of used params: 90.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.0
# value.min(): 15.0
# percentage of used params: 100.00%
# -----> pma, task 3
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.375447
# value.min(): 0.0
# percentage of used params: 87.05%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.633987
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 12.563934
# value.min(): 0.0
# percentage of used params: 78.95%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.3669298
# value.min(): 0.0
# percentage of used params: 93.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.724099
# value.min(): 0.0
# percentage of used params: 80.71%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.2794595
# value.min(): 0.0
# percentage of used params: 92.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2849.9785
# value.min(): 0.0
# percentage of used params: 92.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1061.4623
# value.min(): 1034.1876
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 41.929836
# value.min(): 0.0
# percentage of used params: 92.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.75
# value.min(): 15.75
# percentage of used params: 100.00%
# -----> pma, task 4
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.8316169
# value.min(): 0.0
# percentage of used params: 87.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.326953
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.270539
# value.min(): 0.0
# percentage of used params: 80.10%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.6353267
# value.min(): 0.0
# percentage of used params: 94.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 7.2507925
# value.min(): 0.0
# percentage of used params: 82.45%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7493224
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1986.3479
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1084.3335
# value.min(): 1048.8721
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 29.396854
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.9375
# value.min(): 15.9375
# percentage of used params: 100.00%
# -----> pma, task 5
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.3793936
# value.min(): 0.0
# percentage of used params: 87.15%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.5673747
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.0039363
# value.min(): 0.0
# percentage of used params: 80.62%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.3868651
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.855923
# value.min(): 0.0
# percentage of used params: 84.20%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.1190896
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1867.7998
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1087.4662
# value.min(): 1049.9885
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 27.542421
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.984375
# value.min(): 15.984375
# percentage of used params: 100.00%
# -----> pma, task 6
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.5846786
# value.min(): 0.0
# percentage of used params: 87.21%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.8537636
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 10.969288
# value.min(): 0.0
# percentage of used params: 80.79%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 3.2623863
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 8.088518
# value.min(): 0.0
# percentage of used params: 84.40%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7641383
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1664.5411
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1089.4388
# value.min(): 1054.1675
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 24.60741
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.996094
# value.min(): 15.996094
# percentage of used params: 100.00%
# -----> pma, task 7
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.8487225
# value.min(): 0.0
# percentage of used params: 87.26%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.0435724
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.153074
# value.min(): 0.0
# percentage of used params: 80.86%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5309993
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.557122
# value.min(): 0.0
# percentage of used params: 84.87%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.1605265
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2457.8188
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1087.6969
# value.min(): 1051.6599
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 36.33246
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999023
# value.min(): 15.999023
# percentage of used params: 100.00%
# -----> pma, task 8
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.4083881
# value.min(): 0.0
# percentage of used params: 87.26%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.8328917
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 6.698316
# value.min(): 0.0
# percentage of used params: 80.89%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5397826
# value.min(): 0.0
# percentage of used params: 94.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 9.767842
# value.min(): 0.0
# percentage of used params: 84.96%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.9080486
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2423.9565
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1086.9607
# value.min(): 1051.6952
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 35.73623
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999756
# value.min(): 15.999756
# percentage of used params: 100.00%
# -----> pma, task 9
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.084477
# value.min(): 0.0
# percentage of used params: 87.29%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.2930365
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 11.26388
# value.min(): 0.0
# percentage of used params: 81.25%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.291018
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 4.4580564
# value.min(): 0.0
# percentage of used params: 85.45%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.6528015
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3348.0125
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.7933
# value.min(): 1062.1558
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 49.98298
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999939
# value.min(): 15.999939
# percentage of used params: 100.00%
# -----> pma, task 10
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 7.136893
# value.min(): 0.0
# percentage of used params: 87.34%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 7.7419915
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 13.044404
# value.min(): 0.0
# percentage of used params: 81.38%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.8800573
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 16.780727
# value.min(): 0.0
# percentage of used params: 85.78%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.5446775
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3437.9636
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.2456
# value.min(): 1059.0549
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 51.41835
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999985
# value.min(): 15.999985
# percentage of used params: 100.00%
# -----> pma, task 11
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.1965103
# value.min(): 0.0
# percentage of used params: 87.34%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.541205
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.241883
# value.min(): 0.0
# percentage of used params: 81.46%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.152738
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.264099
# value.min(): 0.0
# percentage of used params: 86.41%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.9278123
# value.min(): 0.0
# percentage of used params: 95.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2509.5518
# value.min(): 0.0
# percentage of used params: 95.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1071.273
# value.min(): 1063.4786
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 37.26553
# value.min(): 0.0
# percentage of used params: 95.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999996
# value.min(): 15.999996
# percentage of used params: 100.00%
# -----> pma, task 12
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.119725
# value.min(): 0.0
# percentage of used params: 87.34%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.6889653
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.89134
# value.min(): 0.0
# percentage of used params: 81.53%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.8576461
# value.min(): 0.0
# percentage of used params: 95.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 10.669827
# value.min(): 0.0
# percentage of used params: 86.57%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.1515405
# value.min(): 0.0
# percentage of used params: 95.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2687.2805
# value.min(): 0.0
# percentage of used params: 95.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1076.3259
# value.min(): 1058.4867
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 40.187763
# value.min(): 0.0
# percentage of used params: 95.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999999
# value.min(): 15.999999
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2       3        4   \
# tasks_idx                          task 1   task 2   task 3  task 4   task 5
# network.phi_body.layers.0.weight  74.4952  86.9591  87.0505  87.137  87.1466
# network.phi_body.layers.0.bias       75.5     87.5     87.5    87.5     87.5
# network.phi_body.layers.1.weight  62.6275    77.03   78.955    80.1    80.62
# network.phi_body.layers.1.bias       85.5     93.5     93.5      94     94.5
# network.phi_body.layers.2.weight    66.25  74.2075  80.7075   82.45   84.205
# network.phi_body.layers.2.bias       86.5       90       92      93     94.5
# network.fc_action.weight             86.5       90       92      93     94.5
# network.fc_action.bias                100      100      100     100      100
# network.fc_critic.weight             86.5       90       92      93     94.5
# network.fc_critic.bias                100      100      100     100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 6   task 7   task 8   task 9  task 10
# network.phi_body.layers.0.weight  87.2067  87.2572  87.2644  87.2933  87.3413
# network.phi_body.layers.0.bias       87.5     87.5     87.5     87.5     87.5
# network.phi_body.layers.1.weight  80.7925   80.855    80.89  81.2475  81.3825
# network.phi_body.layers.1.bias       94.5     94.5     94.5       95       95
# network.phi_body.layers.2.weight     84.4  84.8725    84.96   85.445  85.7825
# network.phi_body.layers.2.bias       94.5       95       95       95       95
# network.fc_action.weight             94.5       95       95       95       95
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight             94.5       95       95       95       95
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                         task 11  task 12
# network.phi_body.layers.0.weight  87.3413  87.3438
# network.phi_body.layers.0.bias       87.5     87.5
# network.phi_body.layers.1.weight  81.4625   81.525
# network.phi_body.layers.1.bias         95       95
# network.phi_body.layers.2.weight  86.4125    86.57
# network.phi_body.layers.2.bias       95.5     95.5
# network.fc_action.weight             95.5     95.5
# network.fc_action.bias                100      100
# network.fc_critic.weight             95.5     95.5
# network.fc_critic.bias                100      100
