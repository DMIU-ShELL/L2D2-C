# %%
import json
import pickle
import numpy as np
import torch
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def load_data(fpath, num_tasks):
    precision_matrices = []
    for task_idx in range(1, num_tasks+1):
        with open(fpath.format(task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
    return precision_matrices

# %%
path = './log/CTgraph-v0-a2c-ewc-pres_ac_neuromod/210930-215351/'
with open('{0}/config.json'.format(path), 'r') as f: 
    config = json.load(f)
num_tasks = config['cl_num_tasks']

# %% [markdown]
# ### Per task precision matrices

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/' + '{0}-vanilla-precision-matrices-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-task-{0}.bin'
precision_matrices = load_data(fpath, num_tasks)

# %%
for i, pm in enumerate(precision_matrices):
    print('-----> pm, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        print('percentage of unused params: {0:.2f}%'.format((v==0.).sum() / len(v)*100))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
# Out:
# -----> pm, task 1
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 1.1875035e-08
# value.min(): 0.0
# percentage of unused params: 61.83%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 1.5674937e-08
# value.min(): 0.0
# percentage of unused params: 22.07%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 6.075808e-11
# value.min(): 0.0
# percentage of unused params: 43.53%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 1.1917183e-09
# value.min(): 0.0
# percentage of unused params: 27.44%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 5.056989e-11
# value.min(): 0.0
# percentage of unused params: 51.68%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 4.3842895e-11
# value.min(): 0.0
# percentage of unused params: 33.40%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 3.121461e-08
# value.min(): 0.0
# percentage of unused params: 43.80%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 8.8890245e-10
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 1.3333247e-10
# value.min(): 0.0
# percentage of unused params: 63.33%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 1.0500281e-10
# value.min(): 0.0
# percentage of unused params: 17.77%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 3.8110567e-14
# value.min(): 0.0
# percentage of unused params: 51.95%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 4.990947e-13
# value.min(): 0.0
# percentage of unused params: 30.66%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 1.25602975e-14
# value.min(): 0.0
# percentage of unused params: 70.25%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 2.8122173e-14
# value.min(): 0.0
# percentage of unused params: 50.59%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 3.5171425e-11
# value.min(): 0.0
# percentage of unused params: 81.50%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 2.0357956e-12
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 0.0006459125
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 2.7814855e-07
# value.min(): 4.5778997e-08
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 1.6712367e-05
# value.min(): 0.0
# percentage of unused params: 60.35%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 7.03918e-09
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 4.7780868e-05
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 1.9141025e-06
# value.min(): 3.6929247e-08
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 3.110785e-06
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 2.523797e-09
# value.min(): 2.523797e-09
# percentage of unused params: 0.00%
# -----> pm, task 2
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 5.8048965e-08
# value.min(): 0.0
# percentage of unused params: 61.64%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 8.0250324e-08
# value.min(): 0.0
# percentage of unused params: 10.74%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 4.032067e-11
# value.min(): 0.0
# percentage of unused params: 25.88%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 7.5293455e-10
# value.min(): 0.0
# percentage of unused params: 15.92%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 8.620759e-12
# value.min(): 0.0
# percentage of unused params: 36.55%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 2.0847036e-11
# value.min(): 0.0
# percentage of unused params: 24.12%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 1.1018386e-09
# value.min(): 0.0
# percentage of unused params: 26.49%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 1.4812472e-10
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 5.287001e-08
# value.min(): 0.0
# percentage of unused params: 64.13%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 2.2267043e-08
# value.min(): 0.0
# percentage of unused params: 11.52%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 2.6515783e-11
# value.min(): 0.0
# percentage of unused params: 33.05%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 9.076773e-11
# value.min(): 0.0
# percentage of unused params: 16.80%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 1.9533574e-12
# value.min(): 0.0
# percentage of unused params: 55.49%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 8.540136e-12
# value.min(): 0.0
# percentage of unused params: 38.09%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 6.444851e-10
# value.min(): 0.0
# percentage of unused params: 70.87%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 1.3864605e-10
# value.min(): 0.0
# percentage of unused params: 34.38%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 1.2132862e-05
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 1.8610464e-08
# value.min(): 5.125762e-09
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 7.4101685e-08
# value.min(): 0.0
# percentage of unused params: 51.56%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 1.011506e-10
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 2.8714447e-07
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 1.19913794e-08
# value.min(): 2.6650163e-10
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 2.877286e-05
# value.min(): 0.0
# percentage of unused params: 34.38%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 1.7441963e-07
# value.min(): 1.7441963e-07
# percentage of unused params: 0.00%
# -----> pm, task 3
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 0.00042020268
# value.min(): 0.0
# percentage of unused params: 55.09%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 0.00043204887
# value.min(): 0.0
# percentage of unused params: 7.42%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 4.8628186e-07
# value.min(): 0.0
# percentage of unused params: 20.73%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 7.6894885e-06
# value.min(): 0.0
# percentage of unused params: 12.60%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 8.652814e-08
# value.min(): 0.0
# percentage of unused params: 31.42%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 2.3609334e-07
# value.min(): 0.0
# percentage of unused params: 21.29%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 0.00029757762
# value.min(): 0.0
# percentage of unused params: 24.04%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 3.602076e-06
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 3.7197016e-05
# value.min(): 0.0
# percentage of unused params: 60.48%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 5.946693e-05
# value.min(): 0.0
# percentage of unused params: 10.74%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 4.279096e-08
# value.min(): 0.0
# percentage of unused params: 26.83%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 2.0076732e-06
# value.min(): 0.0
# percentage of unused params: 12.50%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 3.265207e-08
# value.min(): 0.0
# percentage of unused params: 45.95%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 2.5179784e-07
# value.min(): 0.0
# percentage of unused params: 35.25%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 3.798909e-05
# value.min(): 0.0
# percentage of unused params: 61.59%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 9.537502e-06
# value.min(): 0.0
# percentage of unused params: 25.00%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 2.2777424
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 0.0003363079
# value.min(): 8.591616e-06
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 0.0013735874
# value.min(): 0.0
# percentage of unused params: 51.86%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 8.265458e-07
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 0.0032600393
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 0.0002991724
# value.min(): 2.3677505e-07
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 0.98253083
# value.min(): 0.0
# percentage of unused params: 25.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 0.0081346575
# value.min(): 0.0081346575
# percentage of unused params: 0.00%
# -----> pm, task 4
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 2.9844636e-05
# value.min(): 0.0
# percentage of unused params: 44.42%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 6.4053966e-05
# value.min(): 0.0
# percentage of unused params: 3.91%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 1.8056765e-08
# value.min(): 0.0
# percentage of unused params: 15.30%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 3.19469e-07
# value.min(): 0.0
# percentage of unused params: 8.69%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 3.4676821e-09
# value.min(): 0.0
# percentage of unused params: 29.07%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 4.4223354e-09
# value.min(): 0.0
# percentage of unused params: 21.19%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 4.1544818e-06
# value.min(): 0.0
# percentage of unused params: 24.41%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 5.46069e-08
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 6.7694727e-06
# value.min(): 0.0
# percentage of unused params: 48.08%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 1.7642027e-05
# value.min(): 0.0
# percentage of unused params: 5.66%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 4.4252552e-08
# value.min(): 0.0
# percentage of unused params: 15.55%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 1.4986668e-06
# value.min(): 0.0
# percentage of unused params: 7.71%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 5.520255e-07
# value.min(): 0.0
# percentage of unused params: 39.38%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 1.2223022e-06
# value.min(): 0.0
# percentage of unused params: 33.11%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 6.524728e-05
# value.min(): 0.0
# percentage of unused params: 48.39%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 1.2543669e-06
# value.min(): 0.0
# percentage of unused params: 18.75%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 0.016896993
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 2.4125873e-06
# value.min(): 7.5325306e-07
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 4.8781112e-05
# value.min(): 0.0
# percentage of unused params: 48.54%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 6.3672765e-08
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 0.0014217535
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 1.7733746e-05
# value.min(): 8.2302915e-07
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 0.13241158
# value.min(): 0.0
# percentage of unused params: 18.75%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 0.0011535826
# value.min(): 0.0011535826
# percentage of unused params: 0.00%

# %% [markdown]
# ### Moving average precision matrices across tasks

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/' + '{0}-vanilla-precision-matrices-movavg-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-task-{0}.bin'
precision_matrices = load_data(fpath, num_tasks)

# %%
for i, pm in enumerate(precision_matrices):
    print('-----> pma, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        print('percentage of unused params: {0:.2f}%'.format((v==0.).sum() / len(v) *100))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
# Out:
# -----> pma, task 1
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 8.906277e-09
# value.min(): 0.0
# percentage of unused params: 61.83%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 1.1756203e-08
# value.min(): 0.0
# percentage of unused params: 22.07%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 4.556856e-11
# value.min(): 0.0
# percentage of unused params: 43.53%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 8.937887e-10
# value.min(): 0.0
# percentage of unused params: 27.44%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 3.7927418e-11
# value.min(): 0.0
# percentage of unused params: 51.68%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 3.288217e-11
# value.min(): 0.0
# percentage of unused params: 33.40%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 2.3410959e-08
# value.min(): 0.0
# percentage of unused params: 43.80%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 6.666768e-10
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 9.9999356e-11
# value.min(): 0.0
# percentage of unused params: 63.33%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 7.875211e-11
# value.min(): 0.0
# percentage of unused params: 17.77%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 2.8582924e-14
# value.min(): 0.0
# percentage of unused params: 51.95%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 3.7432102e-13
# value.min(): 0.0
# percentage of unused params: 30.66%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 9.420223e-15
# value.min(): 0.0
# percentage of unused params: 70.25%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 2.109163e-14
# value.min(): 0.0
# percentage of unused params: 50.59%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 2.637857e-11
# value.min(): 0.0
# percentage of unused params: 81.50%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 1.5268467e-12
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 0.00048443436
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 2.0861141e-07
# value.min(): 3.433425e-08
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 1.2534276e-05
# value.min(): 0.0
# percentage of unused params: 60.35%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 5.279385e-09
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 3.5835652e-05
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 1.4355769e-06
# value.min(): 2.7696935e-08
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 2.3330888e-06
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 1.8928477e-09
# value.min(): 1.8928477e-09
# percentage of unused params: 0.00%
# -----> pma, task 2
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 4.397593e-08
# value.min(): 0.0
# percentage of unused params: 48.64%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 6.15469e-08
# value.min(): 0.0
# percentage of unused params: 4.69%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 3.025825e-11
# value.min(): 0.0
# percentage of unused params: 20.92%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 5.6507116e-10
# value.min(): 0.0
# percentage of unused params: 15.92%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 9.714336e-12
# value.min(): 0.0
# percentage of unused params: 36.55%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 1.5635278e-11
# value.min(): 0.0
# percentage of unused params: 24.12%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 6.1623693e-09
# value.min(): 0.0
# percentage of unused params: 26.49%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 1.891306e-10
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 3.967751e-08
# value.min(): 0.0
# percentage of unused params: 52.71%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 1.6701208e-08
# value.min(): 0.0
# percentage of unused params: 4.30%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 1.988751e-11
# value.min(): 0.0
# percentage of unused params: 26.10%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 6.8075795e-11
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 1.465018e-12
# value.min(): 0.0
# percentage of unused params: 50.76%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 6.4051017e-12
# value.min(): 0.0
# percentage of unused params: 32.32%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 4.8995846e-10
# value.min(): 0.0
# percentage of unused params: 65.80%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 1.0398454e-10
# value.min(): 0.0
# percentage of unused params: 34.38%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 0.00013020824
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 6.61107e-08
# value.min(): 1.5040746e-08
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 3.1891452e-06
# value.min(): 0.0
# percentage of unused params: 51.56%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 1.3957092e-09
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 9.06625e-06
# value.min(): 0.0
# percentage of unused params: 50.00%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 3.6788776e-07
# value.min(): 7.1241097e-09
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 2.2162916e-05
# value.min(): 0.0
# percentage of unused params: 34.38%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 1.3128793e-07
# value.min(): 1.3128793e-07
# percentage of unused params: 0.00%
# -----> pma, task 3
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 0.000315152
# value.min(): 0.0
# percentage of unused params: 30.36%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 0.00032403663
# value.min(): 0.0
# percentage of unused params: 0.98%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 3.647114e-07
# value.min(): 0.0
# percentage of unused params: 13.30%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 5.7671164e-06
# value.min(): 0.0
# percentage of unused params: 11.43%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 6.489614e-08
# value.min(): 0.0
# percentage of unused params: 29.91%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 1.7707208e-07
# value.min(): 0.0
# percentage of unused params: 20.41%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 0.00022318377
# value.min(): 0.0
# percentage of unused params: 23.09%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 2.7016044e-06
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 2.7897773e-05
# value.min(): 0.0
# percentage of unused params: 38.70%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 4.460054e-05
# value.min(): 0.0
# percentage of unused params: 2.15%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 3.209322e-08
# value.min(): 0.0
# percentage of unused params: 14.96%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 1.5057549e-06
# value.min(): 0.0
# percentage of unused params: 10.16%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 2.4489054e-08
# value.min(): 0.0
# percentage of unused params: 37.17%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 1.8884839e-07
# value.min(): 0.0
# percentage of unused params: 25.59%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 2.8491819e-05
# value.min(): 0.0
# percentage of unused params: 50.36%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 7.1531263e-06
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 1.7083153
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 0.00025223524
# value.min(): 6.46024e-06
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 0.001030988
# value.min(): 0.0
# percentage of unused params: 48.54%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 6.199093e-07
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 0.002445039
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 0.00022447127
# value.min(): 1.8220514e-07
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 0.73690367
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 0.0061010257
# value.min(): 0.0061010257
# percentage of unused params: 0.00%
# -----> pma, task 4
# key: network.actor_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 7.8790275e-05
# value.min(): 0.0
# percentage of unused params: 21.43%
# key: network.actor_body.layers.0.bias / value.shape: (512,)
# value.max(): 0.00010527172
# value.min(): 3.388831e-14
# percentage of unused params: 0.00%
# key: network.actor_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 9.161578e-08
# value.min(): 0.0
# percentage of unused params: 9.49%
# key: network.actor_body.layers.1.bias / value.shape: (1024,)
# value.max(): 1.4986844e-06
# value.min(): 0.0
# percentage of unused params: 8.59%
# key: network.actor_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 1.6918946e-08
# value.min(): 0.0
# percentage of unused params: 27.63%
# key: network.actor_body.layers.2.bias / value.shape: (1024,)
# value.max(): 4.5567713e-08
# value.min(): 0.0
# percentage of unused params: 20.41%
# key: network.actor_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 5.885847e-05
# value.min(): 0.0
# percentage of unused params: 23.06%
# key: network.actor_body.layers.3.bias / value.shape: (32,)
# value.max(): 7.163563e-07
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.critic_body.layers.0.weight / value.shape: (512, 21)
# value.max(): 6.9761377e-06
# value.min(): 0.0
# percentage of unused params: 28.09%
# key: network.critic_body.layers.0.bias / value.shape: (512,)
# value.max(): 1.323152e-05
# value.min(): 0.0
# percentage of unused params: 0.20%
# key: network.critic_body.layers.1.weight / value.shape: (1024, 512)
# value.max(): 3.3189416e-08
# value.min(): 0.0
# percentage of unused params: 8.62%
# key: network.critic_body.layers.1.bias / value.shape: (1024,)
# value.max(): 1.1240002e-06
# value.min(): 0.0
# percentage of unused params: 7.03%
# key: network.critic_body.layers.2.weight / value.shape: (1024, 1024)
# value.max(): 4.140191e-07
# value.min(): 0.0
# percentage of unused params: 33.07%
# key: network.critic_body.layers.2.bias / value.shape: (1024,)
# value.max(): 9.1672666e-07
# value.min(): 0.0
# percentage of unused params: 24.90%
# key: network.critic_body.layers.3.weight / value.shape: (32, 1024)
# value.max(): 4.893546e-05
# value.min(): 0.0
# percentage of unused params: 43.80%
# key: network.critic_body.layers.3.bias / value.shape: (32,)
# value.max(): 2.7290566e-06
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.fc_action.std.weight / value.shape: (3, 32)
# value.max(): 0.43975157
# value.min(): 0.0
# percentage of unused params: 3.12%
# key: network.fc_action.std.bias / value.shape: (3,)
# value.max(): 6.4868254e-05
# value.min(): 2.1799997e-06
# percentage of unused params: 0.00%
# key: network.fc_action.in_nm.weight / value.shape: (32, 32)
# value.max(): 0.00027130527
# value.min(): 0.0
# percentage of unused params: 48.54%
# key: network.fc_action.in_nm.bias / value.shape: (32,)
# value.max(): 2.0273191e-07
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.weight / value.shape: (3, 32)
# value.max(): 0.001590499
# value.min(): 0.0
# percentage of unused params: 46.88%
# key: network.fc_action.out_nm.bias / value.shape: (3,)
# value.max(): 6.941813e-05
# value.min(): 6.628232e-07
# percentage of unused params: 0.00%
# key: network.fc_critic.weight / value.shape: (1, 32)
# value.max(): 0.2835346
# value.min(): 0.0
# percentage of unused params: 15.62%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 0.0023904433
# value.min(): 0.0023904433
# percentage of unused params: 0.00%
