# %%
import json
import pickle
import numpy as np
import torch
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
# def load_data(fpath, num_tasks):
#     precision_matrices = []
#     for task_idx in range(1, num_tasks+1):
#         with open(fpath.format(task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
#     return precision_matrices

def load_data(fpath, num_runs, num_tasks):
    precision_matrices = []
    for run_idx in range(1, num_runs+1):
        for task_idx in range(1, num_tasks+1):
            with open(fpath.format(run_idx, task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
    return precision_matrices

# %%
path = './log/CTgraph-v0-ppo-scp-with-masking/211125-120853/'
with open('{0}/config.json'.format(path), 'r') as f: 
    config = json.load(f)
num_tasks = config['cl_num_tasks']
num_learning_blocks = config['cl_num_learn_blocks'] # number of times/runs all tasks are repeatedly trained on.

# %% [markdown]
# ### Per task precision matrices

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-run-{0}-task-{1}.bin'
precision_matrices = load_data(fpath, num_learning_blocks, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i % num_tasks +1))
    print('-----> pm, task {0}'.format(i % num_tasks +1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.3698287
# value.min(): 0.0
# percentage of used params: 29.02%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.3882203
# value.min(): 0.0
# percentage of used params: 59.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 4.0597854
# value.min(): 0.0
# percentage of used params: 17.54%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5358948
# value.min(): 0.0
# percentage of used params: 52.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.6712723
# value.min(): 0.0
# percentage of used params: 17.26%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.8618101
# value.min(): 0.0
# percentage of used params: 47.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3588.517
# value.min(): 0.0
# percentage of used params: 74.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.2905
# value.min(): 1045.9596
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 53.13177
# value.min(): 0.0
# percentage of used params: 70.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.0848775
# value.min(): 0.0
# percentage of used params: 31.74%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.1701646
# value.min(): 0.0
# percentage of used params: 60.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.056656
# value.min(): 0.0
# percentage of used params: 19.53%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.4439434
# value.min(): 0.0
# percentage of used params: 51.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 17.399206
# value.min(): 0.0
# percentage of used params: 14.72%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.9197475
# value.min(): 0.0
# percentage of used params: 32.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 6233.5967
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.7385
# value.min(): 1056.4788
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 92.28378
# value.min(): 0.0
# percentage of used params: 45.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.96927
# value.min(): 0.0
# percentage of used params: 24.94%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 6.00186
# value.min(): 0.0
# percentage of used params: 55.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 11.165762
# value.min(): 0.0
# percentage of used params: 15.36%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.987735
# value.min(): 0.0
# percentage of used params: 50.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.8239436
# value.min(): 0.0
# percentage of used params: 15.12%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.6251347
# value.min(): 0.0
# percentage of used params: 44.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4198.69
# value.min(): 0.0
# percentage of used params: 72.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.3639
# value.min(): 1047.4039
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 62.405308
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.8673196
# value.min(): 0.0
# percentage of used params: 29.81%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.9480562
# value.min(): 0.0
# percentage of used params: 57.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.056188
# value.min(): 0.0
# percentage of used params: 18.35%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.4790817
# value.min(): 0.0
# percentage of used params: 49.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 14.733563
# value.min(): 0.0
# percentage of used params: 14.26%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7754883
# value.min(): 0.0
# percentage of used params: 32.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 6290.0527
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1101.0488
# value.min(): 1044.6753
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 91.665634
# value.min(): 0.0
# percentage of used params: 45.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.713607
# value.min(): 0.0
# percentage of used params: 23.60%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.744814
# value.min(): 0.0
# percentage of used params: 54.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 11.583722
# value.min(): 0.0
# percentage of used params: 14.87%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.614465
# value.min(): 0.0
# percentage of used params: 49.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.187553
# value.min(): 0.0
# percentage of used params: 14.59%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.671443
# value.min(): 0.0
# percentage of used params: 39.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3921.807
# value.min(): 0.0
# percentage of used params: 72.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1100.3309
# value.min(): 1048.5533
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 56.979683
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.7489698
# value.min(): 0.0
# percentage of used params: 28.58%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.8272398
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 10.494289
# value.min(): 0.0
# percentage of used params: 17.60%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.802142
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 14.639897
# value.min(): 0.0
# percentage of used params: 13.78%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.1541584
# value.min(): 0.0
# percentage of used params: 30.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 5920.8066
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1090.0963
# value.min(): 1052.4167
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 87.27547
# value.min(): 0.0
# percentage of used params: 45.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 6.6218386
# value.min(): 0.0
# percentage of used params: 23.31%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 6.657978
# value.min(): 0.0
# percentage of used params: 54.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 15.418545
# value.min(): 0.0
# percentage of used params: 14.79%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.9609716
# value.min(): 0.0
# percentage of used params: 49.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.5095606
# value.min(): 0.0
# percentage of used params: 14.53%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.66272396
# value.min(): 0.0
# percentage of used params: 38.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4185.537
# value.min(): 0.0
# percentage of used params: 72.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1087.1162
# value.min(): 1050.8241
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 61.674408
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.1424813
# value.min(): 0.0
# percentage of used params: 28.31%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.2498493
# value.min(): 0.0
# percentage of used params: 56.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 12.182575
# value.min(): 0.0
# percentage of used params: 17.44%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.8796962
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 17.363823
# value.min(): 0.0
# percentage of used params: 13.61%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7554114
# value.min(): 0.0
# percentage of used params: 30.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 6991.039
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1086.7153
# value.min(): 1048.7771
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 102.779945
# value.min(): 0.0
# percentage of used params: 44.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 7.0429997
# value.min(): 0.0
# percentage of used params: 22.90%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 7.0814533
# value.min(): 0.0
# percentage of used params: 54.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 15.627134
# value.min(): 0.0
# percentage of used params: 14.71%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 3.0480533
# value.min(): 0.0
# percentage of used params: 49.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.087296
# value.min(): 0.0
# percentage of used params: 14.40%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.6525785
# value.min(): 0.0
# percentage of used params: 37.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4048.503
# value.min(): 0.0
# percentage of used params: 72.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1079.826
# value.min(): 1057.7329
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 60.05354
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.6096053
# value.min(): 0.0
# percentage of used params: 28.00%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.705838
# value.min(): 0.0
# percentage of used params: 55.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.941676
# value.min(): 0.0
# percentage of used params: 17.22%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.7770524
# value.min(): 0.0
# percentage of used params: 47.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 14.649333
# value.min(): 0.0
# percentage of used params: 13.44%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.9455076
# value.min(): 0.0
# percentage of used params: 29.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 6399.3647
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.063
# value.min(): 1058.0214
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 95.212585
# value.min(): 0.0
# percentage of used params: 44.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 6.721656
# value.min(): 0.0
# percentage of used params: 22.47%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 6.758358
# value.min(): 0.0
# percentage of used params: 54.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 13.870829
# value.min(): 0.0
# percentage of used params: 14.60%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.6237783
# value.min(): 0.0
# percentage of used params: 49.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.9758608
# value.min(): 0.0
# percentage of used params: 14.34%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.64233476
# value.min(): 0.0
# percentage of used params: 37.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4286.9355
# value.min(): 0.0
# percentage of used params: 72.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.1327
# value.min(): 1060.5563
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 64.19651
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.600673
# value.min(): 0.0
# percentage of used params: 27.32%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.6967235
# value.min(): 0.0
# percentage of used params: 55.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 10.7580185
# value.min(): 0.0
# percentage of used params: 16.94%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.658792
# value.min(): 0.0
# percentage of used params: 47.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 17.45816
# value.min(): 0.0
# percentage of used params: 13.27%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.9072843
# value.min(): 0.0
# percentage of used params: 29.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 5804.044
# value.min(): 0.0
# percentage of used params: 48.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1080.019
# value.min(): 1056.8228
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 85.805695
# value.min(): 0.0
# percentage of used params: 44.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3        4   \
# tasks_idx                          task 1   task 2   task 1   task 2   task 1
# network.phi_body.layers.0.weight  29.0216  31.7356  24.9423  29.8149  23.6034
# network.phi_body.layers.0.bias         59       60       55     57.5       54
# network.phi_body.layers.1.weight   17.545  19.5325    15.36    18.35  14.8725
# network.phi_body.layers.1.bias       52.5     51.5     50.5     49.5       49
# network.phi_body.layers.2.weight  17.2625  14.7175  15.1175  14.2625   14.595
# network.phi_body.layers.2.bias       47.5       32       44       32       39
# network.fc_action.weight               74       48     72.5       48     72.5
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight             70.5     45.5     69.5     45.5     69.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 2   task 1   task 2   task 1   task 2
# network.phi_body.layers.0.weight  28.5841  23.3149  28.3101  22.9014  27.9952
# network.phi_body.layers.0.bias         57       54       56       54     55.5
# network.phi_body.layers.1.weight  17.6025  14.7925   17.435  14.7075    17.22
# network.phi_body.layers.1.bias         48       49       48       49     47.5
# network.phi_body.layers.2.weight   13.775    14.53   13.615  14.3975  13.4425
# network.phi_body.layers.2.bias       30.5     38.5       30     37.5     29.5
# network.fc_action.weight               48     72.5       48     72.5       48
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight             45.5     69.5     44.5     69.5     44.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                          task 1   task 2
# network.phi_body.layers.0.weight  22.4736  27.3197
# network.phi_body.layers.0.bias         54       55
# network.phi_body.layers.1.weight  14.5975  16.9375
# network.phi_body.layers.1.bias         49       47
# network.phi_body.layers.2.weight  14.3425    13.27
# network.phi_body.layers.2.bias       37.5     29.5
# network.fc_action.weight             72.5       48
# network.fc_action.bias                100      100
# network.fc_critic.weight             69.5     44.5
# network.fc_critic.bias                100      100

# %% [markdown]
# ### Moving average precision matrices across tasks

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-movavg-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-run-{0}-task-{1}.bin'
precision_matrices = load_data(fpath, num_learning_blocks, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i+1))
    print('-----> pma, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pma, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.5273714
# value.min(): 0.0
# percentage of used params: 29.02%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.5411654
# value.min(): 0.0
# percentage of used params: 59.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.044839
# value.min(): 0.0
# percentage of used params: 17.54%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.151921
# value.min(): 0.0
# percentage of used params: 52.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.0034542
# value.min(): 0.0
# percentage of used params: 17.26%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.64635754
# value.min(): 0.0
# percentage of used params: 47.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2691.3877
# value.min(): 0.0
# percentage of used params: 74.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 808.7179
# value.min(): 784.4697
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 39.848827
# value.min(): 0.0
# percentage of used params: 70.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 12.0
# value.min(): 12.0
# percentage of used params: 100.00%
# -----> pma, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.0636582
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.2364137
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.31318
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.0829575
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 13.049404
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.4398106
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4917.944
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1010.75726
# value.min(): 994.5386
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 72.82777
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.0
# value.min(): 15.0
# percentage of used params: 100.00%
# -----> pma, task 3
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.743912
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.018086
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.656622
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.371219
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.262351
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.5859352
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3477.2788
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1061.4623
# value.min(): 1034.1876
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 51.681248
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.75
# value.min(): 15.75
# percentage of used params: 100.00%
# -----> pma, task 4
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.4626212
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.7168818
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 6.6613164
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.4938536
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 11.865761
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.4086716
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 5394.7363
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1084.3335
# value.min(): 1048.8721
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 79.0425
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.9375
# value.min(): 15.9375
# percentage of used params: 100.00%
# -----> pma, task 5
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.844013
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.1565084
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.413859
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.2005632
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.9664402
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.6253257
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3295.5808
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1087.4662
# value.min(): 1049.9885
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 48.06359
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.984375
# value.min(): 15.984375
# percentage of used params: 100.00%
# -----> pma, task 6
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.4509866
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.7599387
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.9101243
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.358355
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 11.331475
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.689267
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4975.7964
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1089.4388
# value.min(): 1054.1675
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 68.907196
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.996094
# value.min(): 15.996094
# percentage of used params: 100.00%
# -----> pma, task 7
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.4311647
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.7914596
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 12.37246
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.4440615
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.8328688
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.6633294
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3481.1265
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1087.6969
# value.min(): 1051.6599
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 51.254154
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999023
# value.min(): 15.999023
# percentage of used params: 100.00%
# -----> pma, task 8
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.6568613
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.048859
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.861102
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.9026579
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 13.593672
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.3977504
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 5855.899
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1086.9607
# value.min(): 1051.6952
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 86.119934
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999756
# value.min(): 15.999756
# percentage of used params: 100.00%
# -----> pma, task 9
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.697459
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.8199577
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 12.814093
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.5403185
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 3.398418
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.67880636
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3687.561
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.7933
# value.min(): 1062.1558
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 55.101265
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999939
# value.min(): 15.999939
# percentage of used params: 100.00%
# -----> pma, task 10
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.1047316
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.401429
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.878864
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5057477
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 11.669854
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.5381883
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 5308.786
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1072.2456
# value.min(): 1059.0549
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 75.77787
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999985
# value.min(): 15.999985
# percentage of used params: 100.00%
# -----> pma, task 11
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.4591365
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.5583944
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 11.446828
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.2289772
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.9174635
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.67062366
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3772.103
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1071.273
# value.min(): 1063.4786
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 56.225163
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999996
# value.min(): 15.999996
# percentage of used params: 100.00%
# -----> pma, task 12
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.013923
# value.min(): 0.0
# percentage of used params: 49.55%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.2982416
# value.min(): 0.0
# percentage of used params: 80.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.9137
# value.min(): 0.0
# percentage of used params: 33.19%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.7706056
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 13.722723
# value.min(): 0.0
# percentage of used params: 29.14%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.4860754
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4888.7266
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1076.3259
# value.min(): 1058.4867
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 72.41272
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999999
# value.min(): 15.999999
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3        4   \
# tasks_idx                          task 1   task 2   task 3   task 4   task 5
# network.phi_body.layers.0.weight  29.0216  49.5457  49.5457  49.5457  49.5457
# network.phi_body.layers.0.bias         59     80.5     80.5     80.5     80.5
# network.phi_body.layers.1.weight   17.545  33.1875  33.1875  33.1875  33.1875
# network.phi_body.layers.1.bias       52.5     76.5     76.5     76.5     76.5
# network.phi_body.layers.2.weight  17.2625  29.1375  29.1375  29.1375  29.1375
# network.phi_body.layers.2.bias       47.5       66       66       66       66
# network.fc_action.weight               74       88       88       88       88
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight             70.5     86.5     86.5     86.5     86.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 6   task 7   task 8   task 9  task 10
# network.phi_body.layers.0.weight  49.5457  49.5457  49.5457  49.5457  49.5457
# network.phi_body.layers.0.bias       80.5     80.5     80.5     80.5     80.5
# network.phi_body.layers.1.weight  33.1875  33.1875  33.1875  33.1875  33.1875
# network.phi_body.layers.1.bias       76.5     76.5     76.5     76.5     76.5
# network.phi_body.layers.2.weight  29.1375  29.1375  29.1375  29.1375  29.1375
# network.phi_body.layers.2.bias         66       66       66       66       66
# network.fc_action.weight               88       88       88       88       88
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight             86.5     86.5     86.5     86.5     86.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                         task 11  task 12
# network.phi_body.layers.0.weight  49.5457  49.5457
# network.phi_body.layers.0.bias       80.5     80.5
# network.phi_body.layers.1.weight  33.1875  33.1875
# network.phi_body.layers.1.bias       76.5     76.5
# network.phi_body.layers.2.weight  29.1375  29.1375
# network.phi_body.layers.2.bias         66       66
# network.fc_action.weight               88       88
# network.fc_action.bias                100      100
# network.fc_critic.weight             86.5     86.5
# network.fc_critic.bias                100      100
