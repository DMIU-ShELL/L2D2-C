# %%
import json
import pickle
import numpy as np
import torch
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
# def load_data(fpath, num_tasks):
#     precision_matrices = []
#     for task_idx in range(1, num_tasks+1):
#         with open(fpath.format(task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
#     return precision_matrices

def load_data(fpath, num_runs, num_tasks):
    precision_matrices = []
    for run_idx in range(1, num_runs+1):
        for task_idx in range(1, num_tasks+1):
            with open(fpath.format(run_idx, task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
    return precision_matrices

# %%
path = './log/CTgraph-v0-ppo-scp/211109-132026'
with open('{0}/config.json'.format(path), 'r') as f: 
    config = json.load(f)
num_tasks = config['cl_num_tasks']
num_learning_blocks = config['cl_num_learn_blocks'] # number of times/runs all tasks are repeatedly trained on.

# %% [markdown]
# ### Per task precision matrices

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-run-{0}-task-{1}.bin'
precision_matrices = load_data(fpath, num_learning_blocks, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i+1))
    print('-----> pm, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.7275589
# value.min(): 0.0
# percentage of used params: 68.79%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.972063
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.9890591
# value.min(): 0.0
# percentage of used params: 53.70%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.0903298
# value.min(): 0.0
# percentage of used params: 79.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 2.0725162
# value.min(): 0.0
# percentage of used params: 56.84%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.9698045
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2303.045
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1077.2732
# value.min(): 1054.8136
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 34.22134
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 7.086845
# value.min(): 0.0
# percentage of used params: 78.45%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 7.15643
# value.min(): 0.0
# percentage of used params: 80.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 18.81804
# value.min(): 0.0
# percentage of used params: 57.42%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.957672
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 24.598621
# value.min(): 0.0
# percentage of used params: 45.75%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.761916
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 5694.3276
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1090.9275
# value.min(): 1048.7085
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 83.650085
# value.min(): 0.0
# percentage of used params: 66.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 3
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.1759193
# value.min(): 0.0
# percentage of used params: 68.71%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.2813302
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.0077324
# value.min(): 0.0
# percentage of used params: 52.88%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.50491935
# value.min(): 0.0
# percentage of used params: 78.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.34652
# value.min(): 0.0
# percentage of used params: 54.07%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.73225343
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 524.24115
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 282.05066
# value.min(): 253.78453
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 7.414794
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 4
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.6876
# value.min(): 0.0
# percentage of used params: 75.71%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.7041683
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.2701135
# value.min(): 0.0
# percentage of used params: 51.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.8297388
# value.min(): 0.0
# percentage of used params: 70.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.40952
# value.min(): 0.0
# percentage of used params: 37.13%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.9509644
# value.min(): 0.0
# percentage of used params: 57.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1491.1022
# value.min(): 0.0
# percentage of used params: 57.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 277.5342
# value.min(): 256.17505
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 21.354889
# value.min(): 0.0
# percentage of used params: 57.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 5
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.1906593
# value.min(): 0.0
# percentage of used params: 68.64%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.2973913
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.088893
# value.min(): 0.0
# percentage of used params: 52.82%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.5336934
# value.min(): 0.0
# percentage of used params: 78.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.1408169
# value.min(): 0.0
# percentage of used params: 53.52%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.63891023
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 411.5534
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 277.5547
# value.min(): 257.3814
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 5.933465
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 6
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.5693356
# value.min(): 0.0
# percentage of used params: 75.69%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.5847434
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.0268245
# value.min(): 0.0
# percentage of used params: 50.69%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.80708706
# value.min(): 0.0
# percentage of used params: 70.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 7.3307233
# value.min(): 0.0
# percentage of used params: 36.52%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.3381248
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1360.3331
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 278.9147
# value.min(): 252.70897
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 19.494606
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 7
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.0937284
# value.min(): 0.0
# percentage of used params: 68.47%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.1917703
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 0.978819
# value.min(): 0.0
# percentage of used params: 52.70%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.4822814
# value.min(): 0.0
# percentage of used params: 78.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.0088438
# value.min(): 0.0
# percentage of used params: 52.88%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.6119518
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 410.74384
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 272.38956
# value.min(): 262.2345
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 6.0085754
# value.min(): 0.0
# percentage of used params: 76.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 8
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.6029319
# value.min(): 0.0
# percentage of used params: 75.62%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.6186707
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 4.7630677
# value.min(): 0.0
# percentage of used params: 50.64%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.7870265
# value.min(): 0.0
# percentage of used params: 70.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.6231546
# value.min(): 0.0
# percentage of used params: 36.43%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.0969733
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1331.3054
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 276.96686
# value.min(): 250.11278
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 19.218485
# value.min(): 0.0
# percentage of used params: 57.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 9
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 0.8405054
# value.min(): 0.0
# percentage of used params: 68.37%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 0.91584903
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.1293077
# value.min(): 0.0
# percentage of used params: 52.25%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.52845144
# value.min(): 0.0
# percentage of used params: 77.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 0.77887404
# value.min(): 0.0
# percentage of used params: 51.59%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.37877104
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 383.6464
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 273.88678
# value.min(): 258.46017
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 5.5844483
# value.min(): 0.0
# percentage of used params: 76.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 10
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.7499865
# value.min(): 0.0
# percentage of used params: 75.57%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.7671702
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.7504864
# value.min(): 0.0
# percentage of used params: 50.30%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.90540165
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 9.98614
# value.min(): 0.0
# percentage of used params: 35.98%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.7024106
# value.min(): 0.0
# percentage of used params: 56.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1583.8374
# value.min(): 0.0
# percentage of used params: 56.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 277.51392
# value.min(): 259.59207
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 22.815771
# value.min(): 0.0
# percentage of used params: 56.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 11
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 0.8417172
# value.min(): 0.0
# percentage of used params: 67.95%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 0.9171696
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.0195256
# value.min(): 0.0
# percentage of used params: 51.66%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.47746816
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 0.73923427
# value.min(): 0.0
# percentage of used params: 49.95%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.3837891
# value.min(): 0.0
# percentage of used params: 75.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 365.014
# value.min(): 0.0
# percentage of used params: 75.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 277.3348
# value.min(): 260.61307
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 5.3106513
# value.min(): 0.0
# percentage of used params: 75.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%
# -----> pm, task 12
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.5749146
# value.min(): 0.0
# percentage of used params: 75.51%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.5903785
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 4.78124
# value.min(): 0.0
# percentage of used params: 50.18%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.7639633
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.8620768
# value.min(): 0.0
# percentage of used params: 35.74%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.197879
# value.min(): 0.0
# percentage of used params: 56.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1497.9724
# value.min(): 0.0
# percentage of used params: 56.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 270.9615
# value.min(): 264.2615
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 22.103354
# value.min(): 0.0
# percentage of used params: 56.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0
# value.min(): 4.0
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3        4   \
# tasks_idx                          task 1   task 2   task 3   task 4   task 5
# network.phi_body.layers.0.weight  68.7861  78.4519  68.7067  75.7139  68.6394
# network.phi_body.layers.0.bias       69.5       80     69.5       77     69.5
# network.phi_body.layers.1.weight     53.7  57.4225  52.8775    51.13  52.8175
# network.phi_body.layers.1.bias         79       76       78     70.5       78
# network.phi_body.layers.2.weight   56.845  45.7525  54.0725   37.135  53.5175
# network.phi_body.layers.2.bias         77       66     76.5     57.5     76.5
# network.fc_action.weight               77       66     76.5     57.5     76.5
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               77       66     76.5     57.5     76.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 6   task 7   task 8   task 9  task 10
# network.phi_body.layers.0.weight  75.6851  68.4712  75.6178  68.3726  75.5673
# network.phi_body.layers.0.bias         77     69.5       77     69.5       77
# network.phi_body.layers.1.weight  50.6875  52.6975    50.64  52.2475   50.295
# network.phi_body.layers.1.bias         70       78       70     77.5     69.5
# network.phi_body.layers.2.weight   36.525  52.8775  36.4325  51.5925   35.985
# network.phi_body.layers.2.bias         57     76.5       57       76     56.5
# network.fc_action.weight               57     76.5       57       76     56.5
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               57     76.5       57       76     56.5
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                         task 11  task 12
# network.phi_body.layers.0.weight  67.9471  75.5144
# network.phi_body.layers.0.bias       69.5       77
# network.phi_body.layers.1.weight  51.6575   50.175
# network.phi_body.layers.1.bias         77     69.5
# network.phi_body.layers.2.weight   49.945    35.74
# network.phi_body.layers.2.bias       75.5     56.5
# network.fc_action.weight             75.5     56.5
# network.fc_action.bias                100      100
# network.fc_critic.weight             75.5     56.5
# network.fc_critic.bias                100      100

# %% [markdown]
# ### Moving average precision matrices across tasks

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-movavg-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-run-{0}-task-{1}.bin'
precision_matrices = load_data(fpath, num_learning_blocks, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i+1))
    print('-----> pma, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pma, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.045669
# value.min(): 0.0
# percentage of used params: 68.79%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.2290473
# value.min(): 0.0
# percentage of used params: 69.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.4917943
# value.min(): 0.0
# percentage of used params: 53.70%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.81774735
# value.min(): 0.0
# percentage of used params: 79.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.5543871
# value.min(): 0.0
# percentage of used params: 56.84%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.7273534
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1727.2837
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 807.9549
# value.min(): 791.1102
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 25.666004
# value.min(): 0.0
# percentage of used params: 77.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 12.0
# value.min(): 12.0
# percentage of used params: 100.00%
# -----> pma, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 5.3151336
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 5.3673224
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 14.113531
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.2383413
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 18.448967
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.821437
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4288.03
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1020.1843
# value.min(): 984.30896
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 62.991142
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.0
# value.min(): 15.0
# percentage of used params: 100.00%
# -----> pma, task 3
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.3287834
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.3825657
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.5283828
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.7861897
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 4.6122417
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.98443663
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1144.2063
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 457.61523
# value.min(): 445.38446
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 16.8913
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 6.75
# value.min(): 6.75
# percentage of used params: 100.00%
# -----> pma, task 4
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.5978959
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.6135839
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 4.834681
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.8188515
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.18993
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.8895631
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1404.3782
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 319.49677
# value.min(): 303.88135
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 20.23899
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.6875
# value.min(): 4.6875
# percentage of used params: 100.00%
# -----> pma, task 5
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.0151819
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.1120318
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.2086703
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.5047984
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.3018641
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.6502613
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 493.55832
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 284.13635
# value.min(): 271.56656
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 7.334239
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.171875
# value.min(): 4.171875
# percentage of used params: 100.00%
# -----> pma, task 6
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.2698556
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.2823231
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 4.0722857
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.6989871
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.7959065
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.0580225
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1117.7036
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 280.22012
# value.min(): 257.42337
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 16.116804
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0429688
# value.min(): 4.0429688
# percentage of used params: 100.00%
# -----> pma, task 7
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 0.94883335
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.0470579
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.0180714
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.45696044
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.4489766
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.61656106
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 442.2282
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 272.0298
# value.min(): 261.0317
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 6.5061817
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.010742
# value.min(): 4.010742
# percentage of used params: 100.00%
# -----> pma, task 8
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.2755697
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.2880943
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.8268187
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.69847965
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 4.5796103
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.88885635
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1076.7532
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 275.7326
# value.min(): 252.8425
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 15.57566
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0026855
# value.min(): 4.0026855
# percentage of used params: 100.00%
# -----> pma, task 9
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 0.8109084
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 0.8964223
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 0.9943832
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.44246408
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.1449026
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.4173464
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 439.75055
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 274.34824
# value.min(): 261.8356
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 6.3952575
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0006714
# value.min(): 4.0006714
# percentage of used params: 100.00%
# -----> pma, task 10
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.3918225
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.4054892
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 4.552041
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.7669025
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 7.7183466
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 1.3193831
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1260.0447
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 274.123
# value.min(): 260.15295
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 18.248333
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.000168
# value.min(): 4.000168
# percentage of used params: 100.00%
# -----> pma, task 11
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 0.82550234
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 0.9145112
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.1380103
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.46109837
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 1.9295866
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.43099618
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 424.05927
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 276.53186
# value.min(): 260.49805
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 6.169852
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.000042
# value.min(): 4.000042
# percentage of used params: 100.00%
# -----> pma, task 12
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.2681749
# value.min(): 0.0
# percentage of used params: 83.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.2806269
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.8704324
# value.min(): 0.0
# percentage of used params: 70.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.6882471
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.5378857
# value.min(): 0.0
# percentage of used params: 70.73%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.9652932
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1206.1407
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 268.34564
# value.min(): 264.32727
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 17.850561
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 4.0000105
# value.min(): 4.0000105
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3        4   \
# tasks_idx                          task 1   task 2   task 3   task 4   task 5
# network.phi_body.layers.0.weight  68.7861  83.1442  83.1442  83.1442  83.1442
# network.phi_body.layers.0.bias       69.5     83.5     83.5     83.5     83.5
# network.phi_body.layers.1.weight     53.7    70.13    70.13    70.13    70.13
# network.phi_body.layers.1.bias         79       87       87       87       87
# network.phi_body.layers.2.weight   56.845    70.73    70.73    70.73    70.73
# network.phi_body.layers.2.bias         77       89       89       89       89
# network.fc_action.weight               77       89       89       89       89
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               77       89       89       89       89
# network.fc_critic.bias                100      100      100      100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 6   task 7   task 8   task 9  task 10
# network.phi_body.layers.0.weight  83.1442  83.1442  83.1442  83.1442  83.1442
# network.phi_body.layers.0.bias       83.5     83.5     83.5     83.5     83.5
# network.phi_body.layers.1.weight    70.13    70.13    70.13    70.13    70.13
# network.phi_body.layers.1.bias         87       87       87       87       87
# network.phi_body.layers.2.weight    70.73    70.73    70.73    70.73    70.73
# network.phi_body.layers.2.bias         89       89       89       89       89
# network.fc_action.weight               89       89       89       89       89
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               89       89       89       89       89
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                         task 11  task 12
# network.phi_body.layers.0.weight  83.1442  83.1442
# network.phi_body.layers.0.bias       83.5     83.5
# network.phi_body.layers.1.weight    70.13    70.13
# network.phi_body.layers.1.bias         87       87
# network.phi_body.layers.2.weight    70.73    70.73
# network.phi_body.layers.2.bias         89       89
# network.fc_action.weight               89       89
# network.fc_action.bias                100      100
# network.fc_critic.weight               89       89
# network.fc_critic.bias                100      100
