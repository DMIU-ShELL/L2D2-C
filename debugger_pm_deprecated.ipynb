# %%
import json
import pickle
import numpy as np
import torch
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
def load_data(fpath, num_tasks):
    precision_matrices = []
    for task_idx in range(1, num_tasks+1):
        with open(fpath.format(task_idx), 'rb') as f: precision_matrices.append(pickle.load(f))
    return precision_matrices

# %%
path = './log/CTgraph-v0-ppo-scp/211108-154307/'
with open('{0}/config.json'.format(path), 'r') as f: 
    config = json.load(f)
num_tasks = config['cl_num_tasks']
num_learning_blocks = config['cl_num_learn_blocks'] # number of times/runs all tasks are repeatedly trained on.

# %% [markdown]
# ### Per task precision matrices

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/pm/' + '{0}-vanilla-precision-matrices-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-task-{0}.bin'
precision_matrices = load_data(fpath, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i+1))
    print('-----> pm, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pm, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.6612773
# value.min(): 0.0
# percentage of used params: 70.82%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.7295473
# value.min(): 0.0
# percentage of used params: 71.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 2.4907162
# value.min(): 0.0
# percentage of used params: 56.32%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.1495279
# value.min(): 0.0
# percentage of used params: 81.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 0.8849186
# value.min(): 0.0
# percentage of used params: 62.30%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.4664433
# value.min(): 0.0
# percentage of used params: 83.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2184.0234
# value.min(): 0.0
# percentage of used params: 83.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1077.2732
# value.min(): 1054.8136
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 32.365707
# value.min(): 0.0
# percentage of used params: 83.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.3444974
# value.min(): 0.0
# percentage of used params: 76.99%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.375199
# value.min(): 0.0
# percentage of used params: 80.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.722651
# value.min(): 0.0
# percentage of used params: 55.79%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.9778683
# value.min(): 0.0
# percentage of used params: 74.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 27.076035
# value.min(): 0.0
# percentage of used params: 46.37%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 5.042963
# value.min(): 0.0
# percentage of used params: 68.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3422.4316
# value.min(): 0.0
# percentage of used params: 68.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1090.9275
# value.min(): 1048.7085
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 50.21656
# value.min(): 0.0
# percentage of used params: 68.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 3
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.6089048
# value.min(): 0.0
# percentage of used params: 79.69%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.7161179
# value.min(): 0.0
# percentage of used params: 81.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.8148599
# value.min(): 0.0
# percentage of used params: 66.50%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.501065
# value.min(): 0.0
# percentage of used params: 85.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.6888766
# value.min(): 0.0
# percentage of used params: 66.85%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.8215857
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1969.714
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1079.1991
# value.min(): 1060.1251
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 29.27734
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 4
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.5836253
# value.min(): 0.0
# percentage of used params: 79.14%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.6165154
# value.min(): 0.0
# percentage of used params: 81.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.422522
# value.min(): 0.0
# percentage of used params: 60.33%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.9722857
# value.min(): 0.0
# percentage of used params: 78.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 22.472095
# value.min(): 0.0
# percentage of used params: 51.74%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.4569218
# value.min(): 0.0
# percentage of used params: 72.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4316.5166
# value.min(): 0.0
# percentage of used params: 72.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1086.1029
# value.min(): 1051.132
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 63.70736
# value.min(): 0.0
# percentage of used params: 72.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 5
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.9384352
# value.min(): 0.0
# percentage of used params: 80.48%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.0180953
# value.min(): 0.0
# percentage of used params: 82.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.2101207
# value.min(): 0.0
# percentage of used params: 67.75%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.3259908
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.5177245
# value.min(): 0.0
# percentage of used params: 66.62%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.7324867
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2083.4116
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1097.2357
# value.min(): 1044.438
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 30.556421
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 6
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.7948432
# value.min(): 0.0
# percentage of used params: 78.75%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.8204992
# value.min(): 0.0
# percentage of used params: 81.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.617988
# value.min(): 0.0
# percentage of used params: 58.85%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.0231526
# value.min(): 0.0
# percentage of used params: 78.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 24.512001
# value.min(): 0.0
# percentage of used params: 50.39%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.3256137
# value.min(): 0.0
# percentage of used params: 71.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4988.4585
# value.min(): 0.0
# percentage of used params: 71.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.7722
# value.min(): 1056.4082
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 74.13083
# value.min(): 0.0
# percentage of used params: 71.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 7
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.1950622
# value.min(): 0.0
# percentage of used params: 81.01%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.2852669
# value.min(): 0.0
# percentage of used params: 82.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.6014297
# value.min(): 0.0
# percentage of used params: 67.44%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5408055
# value.min(): 0.0
# percentage of used params: 85.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 7.699766
# value.min(): 0.0
# percentage of used params: 64.44%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.7704077
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1785.9385
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1069.7826
# value.min(): 1063.7278
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 26.660831
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 8
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.3146012
# value.min(): 0.0
# percentage of used params: 79.35%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.3358495
# value.min(): 0.0
# percentage of used params: 81.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 12.272115
# value.min(): 0.0
# percentage of used params: 60.85%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.9113688
# value.min(): 0.0
# percentage of used params: 80.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 19.470734
# value.min(): 0.0
# percentage of used params: 53.25%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.647562
# value.min(): 0.0
# percentage of used params: 74.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4432.617
# value.min(): 0.0
# percentage of used params: 74.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1088.3949
# value.min(): 1055.0854
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 65.47516
# value.min(): 0.0
# percentage of used params: 74.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 9
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.6007247
# value.min(): 0.0
# percentage of used params: 80.26%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.6665059
# value.min(): 0.0
# percentage of used params: 81.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 2.700147
# value.min(): 0.0
# percentage of used params: 67.04%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.2395672
# value.min(): 0.0
# percentage of used params: 86.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.7809463
# value.min(): 0.0
# percentage of used params: 64.59%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.5264294
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1694.995
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1071.8033
# value.min(): 1063.8772
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 25.303919
# value.min(): 0.0
# percentage of used params: 86.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 10
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.31871
# value.min(): 0.0
# percentage of used params: 79.07%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.3583536
# value.min(): 0.0
# percentage of used params: 81.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.800295
# value.min(): 0.0
# percentage of used params: 59.74%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.0956364
# value.min(): 0.0
# percentage of used params: 79.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 29.140175
# value.min(): 0.0
# percentage of used params: 51.47%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.503158
# value.min(): 0.0
# percentage of used params: 73.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4666.754
# value.min(): 0.0
# percentage of used params: 73.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1077.7632
# value.min(): 1050.9634
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 69.862686
# value.min(): 0.0
# percentage of used params: 73.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 11
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.3545947
# value.min(): 0.0
# percentage of used params: 77.87%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.4924524
# value.min(): 0.0
# percentage of used params: 80.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.4142
# value.min(): 0.0
# percentage of used params: 63.33%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 3.1920183
# value.min(): 0.0
# percentage of used params: 84.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 10.221299
# value.min(): 0.0
# percentage of used params: 59.48%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.2696881
# value.min(): 0.0
# percentage of used params: 86.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1988.7393
# value.min(): 0.0
# percentage of used params: 86.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1078.1014
# value.min(): 1051.0219
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 29.364761
# value.min(): 0.0
# percentage of used params: 86.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%
# -----> pm, task 12
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 4.0331607
# value.min(): 0.0
# percentage of used params: 79.88%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 4.070181
# value.min(): 0.0
# percentage of used params: 82.00%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 8.887511
# value.min(): 0.0
# percentage of used params: 60.46%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.8040485
# value.min(): 0.0
# percentage of used params: 80.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 25.152227
# value.min(): 0.0
# percentage of used params: 51.34%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.7445748
# value.min(): 0.0
# percentage of used params: 71.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 4362.7314
# value.min(): 0.0
# percentage of used params: 71.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1077.1913
# value.min(): 1048.544
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 64.4986
# value.min(): 0.0
# percentage of used params: 71.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 16.0
# value.min(): 16.0
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3       4   \
# tasks_idx                          task 1   task 2   task 3   task 4  task 5
# network.phi_body.layers.0.weight  70.8173  76.9904  79.6947  79.1442  80.476
# network.phi_body.layers.0.bias       71.5       80     81.5     81.5      82
# network.phi_body.layers.1.weight    56.32  55.7925     66.5    60.33  67.745
# network.phi_body.layers.1.bias         81     74.5       85     78.5    86.5
# network.phi_body.layers.2.weight  62.3025  46.3675  66.8475   51.745  66.625
# network.phi_body.layers.2.bias         83     68.5     88.5       72    88.5
# network.fc_action.weight               83     68.5     88.5       72    88.5
# network.fc_action.bias                100      100      100      100     100
# network.fc_critic.weight               83     68.5     88.5       72    88.5
# network.fc_critic.bias                100      100      100      100     100
#
#                                        5       6        7        8        9   \
# tasks_idx                          task 6  task 7   task 8   task 9  task 10
# network.phi_body.layers.0.weight  78.7476  81.012  79.3534   80.262  79.0721
# network.phi_body.layers.0.bias         81    82.5     81.5     81.5     81.5
# network.phi_body.layers.1.weight  58.8525  67.445    60.85  67.0375    59.74
# network.phi_body.layers.1.bias       78.5      85       80       86       79
# network.phi_body.layers.2.weight    50.39  64.435    53.25   64.595  51.4675
# network.phi_body.layers.2.bias         71      87       74     86.5       73
# network.fc_action.weight               71      87       74     86.5       73
# network.fc_action.bias                100     100      100      100      100
# network.fc_critic.weight               71      87       74     86.5       73
# network.fc_critic.bias                100     100      100      100      100
#
#                                        10       11
# tasks_idx                         task 11  task 12
# network.phi_body.layers.0.weight  77.8678  79.8774
# network.phi_body.layers.0.bias         80       82
# network.phi_body.layers.1.weight  63.3325  60.4575
# network.phi_body.layers.1.bias       84.5       80
# network.phi_body.layers.2.weight    59.48  51.3425
# network.phi_body.layers.2.bias         86     71.5
# network.fc_action.weight               86     71.5
# network.fc_action.bias                100      100
# network.fc_critic.weight               86     71.5
# network.fc_critic.bias                100      100

# %% [markdown]
# ### Moving average precision matrices across tasks

# %%
# precision matrices after executing consolidation method at end of task
fpath = path + '/' + '{0}-vanilla-precision-matrices-movavg-{1}'.format(config['agent_name'], config['env_name'])
fpath = fpath + '-task-{0}.bin'
precision_matrices = load_data(fpath, num_tasks)

# %%
stats_used_params = {}
stats_used_params['tasks_idx'] = []

for i, pm in enumerate(precision_matrices):
    stats_used_params['tasks_idx'].append('task {0}'.format(i+1))
    print('-----> pma, task {0}'.format(i+1))
    for k, v in pm.items():
        v = v.detach().cpu().numpy()
        print('key:', k, '/', 'value.shape:', v.shape)
        print('value.max():', v.max())
        print('value.min():', v.min())
        v = v.reshape(-1)
        used_params = ((v!=0.).sum() / len(v)) *100 # percentage of used parameters
        print('percentage of used params: {0:.2f}%'.format(used_params))
        plt.hist(np.log10((1e+4)*v+1e-12),bins=100)
        #plt.hist(v,bins=100)
        plt.show()
        
        if k not in stats_used_params.keys(): stats_used_params[k] = []
        stats_used_params[k].append(used_params)
# Out:
# -----> pma, task 1
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.245958
# value.min(): 0.0
# percentage of used params: 70.82%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.2971604
# value.min(): 0.0
# percentage of used params: 71.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 1.8680372
# value.min(): 0.0
# percentage of used params: 56.32%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 0.8621459
# value.min(): 0.0
# percentage of used params: 81.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 0.6636889
# value.min(): 0.0
# percentage of used params: 62.30%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 0.34983248
# value.min(): 0.0
# percentage of used params: 83.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1638.0176
# value.min(): 0.0
# percentage of used params: 83.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 807.9549
# value.min(): 791.1102
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 24.27428
# value.min(): 0.0
# percentage of used params: 83.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 12.0
# value.min(): 12.0
# percentage of used params: 100.00%
# -----> pma, task 2
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.5092616
# value.min(): 0.0
# percentage of used params: 82.80%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.5326424
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.7919884
# value.min(): 0.0
# percentage of used params: 69.69%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.4874073
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 20.307026
# value.min(): 0.0
# percentage of used params: 73.12%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.7822223
# value.min(): 0.0
# percentage of used params: 91.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2601.0454
# value.min(): 0.0
# percentage of used params: 91.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1020.1843
# value.min(): 984.30896
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 38.173874
# value.min(): 0.0
# percentage of used params: 91.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.0
# value.min(): 15.0
# percentage of used params: 100.00%
# -----> pma, task 3
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.034656
# value.min(): 0.0
# percentage of used params: 83.06%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.1570494
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 2.9545817
# value.min(): 0.0
# percentage of used params: 71.56%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.3705311
# value.min(): 0.0
# percentage of used params: 87.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.5928617
# value.min(): 0.0
# percentage of used params: 76.63%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.1297972
# value.min(): 0.0
# percentage of used params: 92.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1943.8206
# value.min(): 0.0
# percentage of used params: 92.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1064.4453
# value.min(): 1041.5839
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 28.833286
# value.min(): 0.0
# percentage of used params: 92.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.75
# value.min(): 15.75
# percentage of used params: 100.00%
# -----> pma, task 4
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.850801
# value.min(): 0.0
# percentage of used params: 83.07%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.911146
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.121
# value.min(): 0.0
# percentage of used params: 72.20%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.6646898
# value.min(): 0.0
# percentage of used params: 87.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 17.754244
# value.min(): 0.0
# percentage of used params: 77.50%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.0572212
# value.min(): 0.0
# percentage of used params: 92.50%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3427.2446
# value.min(): 0.0
# percentage of used params: 92.50%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1074.9731
# value.min(): 1049.3416
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 50.6661
# value.min(): 0.0
# percentage of used params: 92.50%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.9375
# value.min(): 15.9375
# percentage of used params: 100.00%
# -----> pma, task 5
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.6546698
# value.min(): 0.0
# percentage of used params: 83.07%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.9263663
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.0039582
# value.min(): 0.0
# percentage of used params: 72.69%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.2153205
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.197402
# value.min(): 0.0
# percentage of used params: 78.48%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.1996205
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2257.487
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1091.67
# value.min(): 1049.1248
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 33.16205
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.984375
# value.min(): 15.984375
# percentage of used params: 100.00%
# -----> pma, task 6
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.2790034
# value.min(): 0.0
# percentage of used params: 83.09%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.3019092
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 6.8038626
# value.min(): 0.0
# percentage of used params: 72.76%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.7177333
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 19.446222
# value.min(): 0.0
# percentage of used params: 78.57%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.8465207
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3874.4895
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1073.0989
# value.min(): 1060.8936
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 57.62613
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.996094
# value.min(): 15.996094
# percentage of used params: 100.00%
# -----> pma, task 7
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.7950981
# value.min(): 0.0
# percentage of used params: 83.09%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.054448
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 3.0499845
# value.min(): 0.0
# percentage of used params: 72.84%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.3570404
# value.min(): 0.0
# percentage of used params: 88.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 6.075458
# value.min(): 0.0
# percentage of used params: 78.69%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.2366543
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2105.225
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1068.6428
# value.min(): 1065.0897
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 31.560654
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999023
# value.min(): 15.999023
# percentage of used params: 100.00%
# -----> pma, task 8
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.8856554
# value.min(): 0.0
# percentage of used params: 83.09%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.9059238
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 9.360284
# value.min(): 0.0
# percentage of used params: 73.13%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.2618089
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 15.831553
# value.min(): 0.0
# percentage of used params: 79.12%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.9908748
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3638.213
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1082.8137
# value.min(): 1057.5865
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 53.77258
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999756
# value.min(): 15.999756
# percentage of used params: 100.00%
# -----> pma, task 9
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 1.3007128
# value.min(): 0.0
# percentage of used params: 83.12%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 1.3789654
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 2.4106612
# value.min(): 0.0
# percentage of used params: 73.17%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.1019444
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 5.469026
# value.min(): 0.0
# percentage of used params: 79.21%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.0596368
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 1810.647
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1068.74
# value.min(): 1062.6366
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 27.12059
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999939
# value.min(): 15.999939
# percentage of used params: 100.00%
# -----> pma, task 10
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.3948274
# value.min(): 0.0
# percentage of used params: 83.12%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.450987
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.3710446
# value.min(): 0.0
# percentage of used params: 73.24%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.7661058
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 22.279774
# value.min(): 0.0
# percentage of used params: 79.30%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.895267
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3647.448
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1075.5073
# value.min(): 1055.3754
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 54.512493
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999985
# value.min(): 15.999985
# percentage of used params: 100.00%
# -----> pma, task 11
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 2.5901642
# value.min(): 0.0
# percentage of used params: 83.12%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 2.8146806
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 5.5769343
# value.min(): 0.0
# percentage of used params: 73.25%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 2.4074545
# value.min(): 0.0
# percentage of used params: 88.50%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 8.009058
# value.min(): 0.0
# percentage of used params: 79.31%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 2.6008527
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 2320.83
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1075.8545
# value.min(): 1052.1102
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 34.432404
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999996
# value.min(): 15.999996
# percentage of used params: 100.00%
# -----> pma, task 12
# key: network.phi_body.layers.0.weight / value.shape: (200, 208)
# value.max(): 3.325775
# value.min(): 0.0
# percentage of used params: 83.12%
# key: network.phi_body.layers.0.bias / value.shape: (200,)
# value.max(): 3.3924677
# value.min(): 0.0
# percentage of used params: 83.50%
# key: network.phi_body.layers.1.weight / value.shape: (200, 200)
# value.max(): 7.085408
# value.min(): 0.0
# percentage of used params: 73.49%
# key: network.phi_body.layers.1.bias / value.shape: (200,)
# value.max(): 1.5498636
# value.min(): 0.0
# percentage of used params: 89.00%
# key: network.phi_body.layers.2.weight / value.shape: (200, 200)
# value.max(): 20.236639
# value.min(): 0.0
# percentage of used params: 79.50%
# key: network.phi_body.layers.2.bias / value.shape: (200,)
# value.max(): 3.0384262
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.weight / value.shape: (3, 200)
# value.max(): 3508.481
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_action.bias / value.shape: (3,)
# value.max(): 1073.7083
# value.min(): 1055.3716
# percentage of used params: 100.00%
# key: network.fc_critic.weight / value.shape: (1, 200)
# value.max(): 52.271023
# value.min(): 0.0
# percentage of used params: 93.00%
# key: network.fc_critic.bias / value.shape: (1,)
# value.max(): 15.999999
# value.min(): 15.999999
# percentage of used params: 100.00%

# %%
df_stats_used_params = pd.DataFrame(stats_used_params)
df_stats_used_params.T
# Out:
#                                        0        1        2        3        4   \
# tasks_idx                          task 1   task 2   task 3   task 4   task 5
# network.phi_body.layers.0.weight  70.8173  82.8029  83.0577  83.0697  83.0721
# network.phi_body.layers.0.bias       71.5     83.5     83.5     83.5     83.5
# network.phi_body.layers.1.weight    56.32   69.695    71.56  72.1975   72.695
# network.phi_body.layers.1.bias         81       87       87     87.5       88
# network.phi_body.layers.2.weight  62.3025  73.1175    76.63  77.4975   78.485
# network.phi_body.layers.2.bias         83     91.5     92.5     92.5       93
# network.fc_action.weight               83     91.5     92.5     92.5       93
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               83     91.5     92.5     92.5       93
# network.fc_critic.bias                100      100      100      100      100
#
#                                        5        6        7        8        9   \
# tasks_idx                          task 6   task 7   task 8   task 9  task 10
# network.phi_body.layers.0.weight  83.0889  83.0938  83.0938  83.1154  83.1154
# network.phi_body.layers.0.bias       83.5     83.5     83.5     83.5     83.5
# network.phi_body.layers.1.weight  72.7625   72.845  73.1325  73.1675  73.2425
# network.phi_body.layers.1.bias         88       88     88.5     88.5     88.5
# network.phi_body.layers.2.weight    78.57  78.6925  79.1225  79.2125  79.3025
# network.phi_body.layers.2.bias         93       93       93       93       93
# network.fc_action.weight               93       93       93       93       93
# network.fc_action.bias                100      100      100      100      100
# network.fc_critic.weight               93       93       93       93       93
# network.fc_critic.bias                100      100      100      100      100
#
#                                        10       11
# tasks_idx                         task 11  task 12
# network.phi_body.layers.0.weight  83.1154  83.1154
# network.phi_body.layers.0.bias       83.5     83.5
# network.phi_body.layers.1.weight  73.2475    73.49
# network.phi_body.layers.1.bias       88.5       89
# network.phi_body.layers.2.weight   79.305  79.4975
# network.phi_body.layers.2.bias         93       93
# network.fc_action.weight               93       93
# network.fc_action.bias                100      100
# network.fc_critic.weight               93       93
# network.fc_critic.bias                100      100
